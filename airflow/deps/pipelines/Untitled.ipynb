# %%
from pipelines.concat_task import concat_csvs_to_parquet
import columns

# %%
df = concat_csvs_to_parquet(data_type='sale', columns_to_skip=(columns.DESC))
# Out:
# concat_task.py 21:53:07 INFO: Will concat raw files newer than 2000-01-01 00:00:00
# concat_task.py 21:53:07 INFO: Found 210 raw files newer than previous concat date
# s3_client.py 21:53:07 INFO: Downloading sale/raw/2019-06-26T23-07-32.csv from flats-data bucket ...
# s3_client.py 21:53:27 INFO: Successfully downloaded sale/raw/2019-06-26T23-07-32.csv from flats-data bucket.
# s3_client.py 21:53:28 INFO: Downloading sale/raw/2019-06-27T02-00-07.csv from flats-data bucket ...
# s3_client.py 21:54:10 INFO: Successfully downloaded sale/raw/2019-06-27T02-00-07.csv from flats-data bucket.
# s3_client.py 21:54:10 INFO: Downloading sale/raw/2019-06-28T00-05-02.csv from flats-data bucket ...
# s3_client.py 21:54:52 INFO: Successfully downloaded sale/raw/2019-06-28T00-05-02.csv from flats-data bucket.
# s3_client.py 21:54:52 INFO: Downloading sale/raw/2019-07-01T17-56-32.csv from flats-data bucket ...
# ...

# %%
df_ = df
