# %%
from s3_client import s3_client
import common

# %%
s3_client = s3_client()
# Out:
# credentials.py 13:10:42 INFO: Found credentials in shared credentials file: ~/.aws/credentials

# %%
df = s3_client.read_newest_df_from_s3(common.PREDICTED_DATA_PATH, 'sale')
# Out:
# s3_client.py 13:12:00 INFO: Downloading sale/predicted/sale_predicted_2019_12_31T13_08_25.parquet from flats-data bucket ...
# s3_client.py 13:12:09 INFO: Successfully downloaded sale/predicted/sale_predicted_2019_12_31T13_08_25.parquet from flats-data bucket.

# %%
df
# Out:
#         balcony__offer  basement__clean  building_height__offer  \
# 1                  1.0              1.0                     3.0
# 3                  1.0              0.0                     2.0
# 4                  1.0              1.0                     3.0
# 5                  1.0              1.0                     4.0
# 7                  1.0              1.0                     8.0
# ...                ...              ...                     ...
# 204995             1.0              0.0                     7.0
# 204996             1.0              0.0                     6.0
# 204997             1.0              0.0                     2.0
# 204998             1.0              0.0                     6.0
# 204999             1.0              0.0                     2.0
#
#         building_material__offer  building_type__offer  building_year__offer  \
# 1                              3                     1                2019.0
# 3                              3                     1                2019.0
# 4                              3                     1                2008.0
# 5                              3                     2                2019.0
# 7                              3                     3                2019.0
# ...                          ...                   ...                   ...
# 204995                         3                     3                2020.0
# 204996                         3                     3                2021.0
# 204997                         3                     3                2020.0
# 204998                         3                     3                2012.0
# 204999                         3                     3                2020.0
#
#        date_added__offer date_refreshed__offer  desc_len__offer  \
# 1             2019-12-30            2019-12-21           1768.0
# 3             2019-12-30            2019-12-30            739.0
# 4             2019-12-30            2019-12-29           1351.0
# 5             2019-12-30            2019-12-30           1401.0
# 7             2019-12-30            2019-12-30           1993.0
# ...                  ...                   ...              ...
# 204995        2019-05-31            2019-05-31           1588.0
# 204996        2019-05-31            2019-05-31           2705.0
# 204997        2019-06-03            2019-06-04           3513.0
# 204998        2019-06-03            2019-06-03           1104.0
# 204999        2019-06-03            2019-06-03           3391.0
#
#         direct__offer  ...  taras__offer  telecom__clean  view_count__offer  \
# 1                 0.0  ...           0.0             0.0               41.0
# 3                 0.0  ...           0.0             0.0               32.0
# 4                 0.0  ...           0.0             0.0               62.0
# 5                 0.0  ...           0.0             0.0               12.0
# 7                 0.0  ...           0.0             0.0               12.0
# ...               ...  ...           ...             ...                ...
# 204995            0.0  ...           1.0             0.0               11.0
# 204996            0.0  ...           0.0             0.0               26.0
# 204997            0.0  ...           1.0             0.0                9.0
# 204998            0.0  ...           0.0             0.0               12.0
# 204999            0.0  ...           0.0             0.0                7.0
#
#         water__offer  cluster_mean_price_m2__feature  \
# 1                  0                       192438.69
# 3                  0                       257156.42
# 4                  0                       210567.52
# 5                  0                       223183.56
# 7                  1                       267886.35
# ...              ...                             ...
# 204995             0                       449769.01
# 204996             0                       730434.37
# 204997             0                       449769.01
# 204998             0                       730434.37
# 204999             0                       449769.01
#
#         cluster_mean_price__feature  cluster_id__feature  \
# 1                     207222.222222                  894
# 3                     236386.500000                 1173
# 4                     299000.000000                  979
# 5                     194800.000000                 1041
# 7                     308409.433333                 1209
# ...                             ...                  ...
# 204995                424430.361257                 1482
# 204996                709303.933649                 1539
# 204997                424430.361257                 1482
# 204998                709303.933649                 1539
# 204999                424430.361257                 1482
#
#         cluster_center_dist_km__feature  cluster_coords_factor__feature  \
# 1                                 13.63                   205595.095495
# 3                                  4.29                   305740.661568
# 4                                  0.67                   336580.394182
# 5                                  0.88                   341583.320493
# 7                                  7.68                   298741.720628
# ...                                 ...                             ...
# 204995                             3.02                   561735.410843
# 204996                             4.91                   854006.416073
# 204997                             7.72                   501318.471663
# 204998                             4.55                   862020.456225
# 204999                             7.72                   501318.471663
#
#         sale__prediction
# 1            3373.813469
# 3            3374.245369
# 4            3396.194479
# 5            3397.938079
# 7            3402.703745
# ...                  ...
# 204995       3401.824363
# 204996      10327.566023
# 204997       3373.365987
# 204998      10738.784564
# 204999       3373.365987
#
# [194172 rows x 43 columns]

# %%
import numpy as np
df.loc['sale__predictions' == max(abs(df['price_m2__offer'] - df['sale__prediction']))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-6d2926669eeb> in <module>
#       1 import numpy as np
# ----> 2 df.loc['sale__predictions' == max(abs(df['price_m2__offer'] - df['sale__prediction']))]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False

# %%
np.median
