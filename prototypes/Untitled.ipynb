# %%
import pandas as pd
df = pd.read_parquet('sale_clean_2019_09_09T19_29_51.parquet')

# %%
from auto_ml import Predictor
from auto_ml.utils_models import load_ml_model
from sklearn.model_selection import train_test_split

# Load data
df = df.drop(['price', 'offer_id'], axis=1)
df_train, df_test = train_test_split(df)


# Tell auto_ml which column is 'output'
# Also note columns that aren't purely numerical
# Examples include ['nlp', 'date', 'categorical', 'ignore']
column_descriptions = {
  'price_m2': 'output'
}

ml_predictor = Predictor(type_of_estimator='regressor', column_descriptions=column_descriptions)

ml_predictor.train(df_train)

# Score the model on test data
test_score = ml_predictor.score(df_test, df_test['price_m2'])

# auto_ml is specifically tuned for running in production
# It can get predictions on an individual row (passed in as a dictionary)
# A single prediction like this takes ~1 millisecond
# Here we will demonstrate saving the trained model, and loading it again
file_name = ml_predictor.save()

trained_model = load_ml_model(file_name)

# .predict and .predict_proba take in either:
# A pandas DataFrame
# A list of dictionaries
# A single dictionary (optimized for speed in production evironments)
predictions = trained_model.predict(df_test)
print(predictions)
# Out:
# Welcome to auto_ml! We're about to go through and make sense of your data using machine learning, and give you a production-ready pipeline to get predictions with.
#
# If you have any issues, or new feature ideas, let us know at http://auto.ml
# You are running on version 2.9.9
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
# Running basic data cleaning
# Fitting DataFrameVectorizer
# Performing feature selection
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
#
#
# ********************************************************************************************
# About to fit the pipeline for the model GradientBoostingRegressor to predict price_m2
# Started at:
# 2019-09-09 21:50:28
# [1] random_holdout_set_from_training_data's score is: -3421.179
# [2] random_holdout_set_from_training_data's score is: -3319.382
# [3] random_holdout_set_from_training_data's score is: -3231.577
# [4] random_holdout_set_from_training_data's score is: -3144.912
# [5] random_holdout_set_from_training_data's score is: -3075.161
# [6] random_holdout_set_from_training_data's score is: -3014.694
# [7] random_holdout_set_from_training_data's score is: -2957.846
# [8] random_holdout_set_from_training_data's score is: -2918.916
# [9] random_holdout_set_from_training_data's score is: -2874.234
# [10] random_holdout_set_from_training_data's score is: -2844.143
# [11] random_holdout_set_from_training_data's score is: -2791.781
# [12] random_holdout_set_from_training_data's score is: -2745.16
# [13] random_holdout_set_from_training_data's score is: -2712.904
# [14] random_holdout_set_from_training_data's score is: -2679.31
# [15] random_holdout_set_from_training_data's score is: -2657.808
# [16] random_holdout_set_from_training_data's score is: -2633.946
# [17] random_holdout_set_from_training_data's score is: -2605.766
# [18] random_holdout_set_from_training_data's score is: -2589.903
# [19] random_holdout_set_from_training_data's score is: -2570.552
# [20] random_holdout_set_from_training_data's score is: -2551.17
# [21] random_holdout_set_from_training_data's score is: -2535.766
# [22] random_holdout_set_from_training_data's score is: -2511.57
# [23] random_holdout_set_from_training_data's score is: -2498.382
# [24] random_holdout_set_from_training_data's score is: -2489.144
# [25] random_holdout_set_from_training_data's score is: -2478.976
# [26] random_holdout_set_from_training_data's score is: -2464.867
# [27] random_holdout_set_from_training_data's score is: -2453.933
# [28] random_holdout_set_from_training_data's score is: -2443.149
# [29] random_holdout_set_from_training_data's score is: -2430.208
# [30] random_holdout_set_from_training_data's score is: -2422.186
# [31] random_holdout_set_from_training_data's score is: -2411.173
# [32] random_holdout_set_from_training_data's score is: -2401.19
# [33] random_holdout_set_from_training_data's score is: -2393.571
# [34] random_holdout_set_from_training_data's score is: -2377.313
# [35] random_holdout_set_from_training_data's score is: -2368.824
# [36] random_holdout_set_from_training_data's score is: -2357.963
# [37] random_holdout_set_from_training_data's score is: -2349.076
# [38] random_holdout_set_from_training_data's score is: -2336.68
# [39] random_holdout_set_from_training_data's score is: -2331.921
# [40] random_holdout_set_from_training_data's score is: -2322.879
# [41] random_holdout_set_from_training_data's score is: -2309.562
# [42] random_holdout_set_from_training_data's score is: -2304.136
# [43] random_holdout_set_from_training_data's score is: -2295.151
# [44] random_holdout_set_from_training_data's score is: -2282.408
# [45] random_holdout_set_from_training_data's score is: -2276.747
# [46] random_holdout_set_from_training_data's score is: -2268.551
# [47] random_holdout_set_from_training_data's score is: -2258.914
# [48] random_holdout_set_from_training_data's score is: -2248.412
# [49] random_holdout_set_from_training_data's score is: -2243.097
# [50] random_holdout_set_from_training_data's score is: -2238.787
# [52] random_holdout_set_from_training_data's score is: -2227.559
# [54] random_holdout_set_from_training_data's score is: -2211.521
# [56] random_holdout_set_from_training_data's score is: -2198.394
# [58] random_holdout_set_from_training_data's score is: -2179.076
# [60] random_holdout_set_from_training_data's score is: -2170.518
# [62] random_holdout_set_from_training_data's score is: -2160.815
# [64] random_holdout_set_from_training_data's score is: -2146.145
# [66] random_holdout_set_from_training_data's score is: -2137.915
# [68] random_holdout_set_from_training_data's score is: -2131.714
# [70] random_holdout_set_from_training_data's score is: -2124.109
# [72] random_holdout_set_from_training_data's score is: -2114.871
# [74] random_holdout_set_from_training_data's score is: -2107.48
# [76] random_holdout_set_from_training_data's score is: -2096.766
# [78] random_holdout_set_from_training_data's score is: -2090.419
# [80] random_holdout_set_from_training_data's score is: -2084.948
# [82] random_holdout_set_from_training_data's score is: -2078.268
# [84] random_holdout_set_from_training_data's score is: -2068.212
# [86] random_holdout_set_from_training_data's score is: -2061.834
# [88] random_holdout_set_from_training_data's score is: -2058.421
# [90] random_holdout_set_from_training_data's score is: -2052.887
# [92] random_holdout_set_from_training_data's score is: -2048.846
# [94] random_holdout_set_from_training_data's score is: -2042.582
# [96] random_holdout_set_from_training_data's score is: -2036.624
# [98] random_holdout_set_from_training_data's score is: -2032.34
# [100] random_holdout_set_from_training_data's score is: -2025.966
# [103] random_holdout_set_from_training_data's score is: -2018.864
# [106] random_holdout_set_from_training_data's score is: -2007.709
# [109] random_holdout_set_from_training_data's score is: -2000.401
# [112] random_holdout_set_from_training_data's score is: -1990.328
# [115] random_holdout_set_from_training_data's score is: -1981.095
# [118] random_holdout_set_from_training_data's score is: -1974.958
# [121] random_holdout_set_from_training_data's score is: -1968.254
# [124] random_holdout_set_from_training_data's score is: -1963.489
# [127] random_holdout_set_from_training_data's score is: -1958.776
# [130] random_holdout_set_from_training_data's score is: -1951.967
# [133] random_holdout_set_from_training_data's score is: -1947.463
# [136] random_holdout_set_from_training_data's score is: -1945.087
# [139] random_holdout_set_from_training_data's score is: -1936.41
# [142] random_holdout_set_from_training_data's score is: -1931.098
# [145] random_holdout_set_from_training_data's score is: -1927.634
# [148] random_holdout_set_from_training_data's score is: -1925.322
# [151] random_holdout_set_from_training_data's score is: -1917.137
# [154] random_holdout_set_from_training_data's score is: -1913.468
# [157] random_holdout_set_from_training_data's score is: -1912.198
# [160] random_holdout_set_from_training_data's score is: -1906.928
# [163] random_holdout_set_from_training_data's score is: -1903.223
# [166] random_holdout_set_from_training_data's score is: -1899.614
# [169] random_holdout_set_from_training_data's score is: -1896.737
# [172] random_holdout_set_from_training_data's score is: -1894.299
# [175] random_holdout_set_from_training_data's score is: -1889.744
# [178] random_holdout_set_from_training_data's score is: -1885.164
# [181] random_holdout_set_from_training_data's score is: -1881.66
# [184] random_holdout_set_from_training_data's score is: -1875.409
# [187] random_holdout_set_from_training_data's score is: -1872.039
# [190] random_holdout_set_from_training_data's score is: -1868.752
# [193] random_holdout_set_from_training_data's score is: -1867.717
# [196] random_holdout_set_from_training_data's score is: -1865.347
# [199] random_holdout_set_from_training_data's score is: -1862.955
# [202] random_holdout_set_from_training_data's score is: -1861.38
# [205] random_holdout_set_from_training_data's score is: -1857.757
# [208] random_holdout_set_from_training_data's score is: -1856.79
# [211] random_holdout_set_from_training_data's score is: -1855.371
# [214] random_holdout_set_from_training_data's score is: -1853.974
# [217] random_holdout_set_from_training_data's score is: -1849.222
# [220] random_holdout_set_from_training_data's score is: -1847.441
# [223] random_holdout_set_from_training_data's score is: -1846.093
# [226] random_holdout_set_from_training_data's score is: -1844.028
# [229] random_holdout_set_from_training_data's score is: -1839.421
# [232] random_holdout_set_from_training_data's score is: -1838.83
# [235] random_holdout_set_from_training_data's score is: -1835.132
# [238] random_holdout_set_from_training_data's score is: -1832.382
# [241] random_holdout_set_from_training_data's score is: -1830.699
# [244] random_holdout_set_from_training_data's score is: -1827.934
# [247] random_holdout_set_from_training_data's score is: -1825.684
# [250] random_holdout_set_from_training_data's score is: -1825.404
# [255] random_holdout_set_from_training_data's score is: -1823.523
# [260] random_holdout_set_from_training_data's score is: -1818.969
# [265] random_holdout_set_from_training_data's score is: -1816.256
# [270] random_holdout_set_from_training_data's score is: -1813.884
# [275] random_holdout_set_from_training_data's score is: -1812.818
# [280] random_holdout_set_from_training_data's score is: -1810.079
# [285] random_holdout_set_from_training_data's score is: -1807.813
# [290] random_holdout_set_from_training_data's score is: -1805.048
# [295] random_holdout_set_from_training_data's score is: -1800.705
# [300] random_holdout_set_from_training_data's score is: -1796.302
# [305] random_holdout_set_from_training_data's score is: -1792.011
# [310] random_holdout_set_from_training_data's score is: -1789.209
# [315] random_holdout_set_from_training_data's score is: -1787.427
# [320] random_holdout_set_from_training_data's score is: -1786.087
# [325] random_holdout_set_from_training_data's score is: -1782.025
# [330] random_holdout_set_from_training_data's score is: -1780.83
# [335] random_holdout_set_from_training_data's score is: -1779.163
# [340] random_holdout_set_from_training_data's score is: -1777.821
# [345] random_holdout_set_from_training_data's score is: -1776.364
# [350] random_holdout_set_from_training_data's score is: -1773.443
# [355] random_holdout_set_from_training_data's score is: -1772.013
# [360] random_holdout_set_from_training_data's score is: -1771.281
# [365] random_holdout_set_from_training_data's score is: -1767.6
# [370] random_holdout_set_from_training_data's score is: -1765.613
# [375] random_holdout_set_from_training_data's score is: -1764.741
# [380] random_holdout_set_from_training_data's score is: -1761.153
# [385] random_holdout_set_from_training_data's score is: -1758.626
# [390] random_holdout_set_from_training_data's score is: -1756.049
# [395] random_holdout_set_from_training_data's score is: -1753.173
# [400] random_holdout_set_from_training_data's score is: -1752.676
# [405] random_holdout_set_from_training_data's score is: -1750.936
# [410] random_holdout_set_from_training_data's score is: -1749.319
# [415] random_holdout_set_from_training_data's score is: -1746.902
# [420] random_holdout_set_from_training_data's score is: -1744.413
# [425] random_holdout_set_from_training_data's score is: -1741.753
# [430] random_holdout_set_from_training_data's score is: -1740.147
# [435] random_holdout_set_from_training_data's score is: -1738.893
# [440] random_holdout_set_from_training_data's score is: -1737.149
# [445] random_holdout_set_from_training_data's score is: -1735.777
# [450] random_holdout_set_from_training_data's score is: -1734.184
# [455] random_holdout_set_from_training_data's score is: -1733.295
# [460] random_holdout_set_from_training_data's score is: -1732.049
# [465] random_holdout_set_from_training_data's score is: -1730.328
# [470] random_holdout_set_from_training_data's score is: -1728.478
# [475] random_holdout_set_from_training_data's score is: -1726.751
# [480] random_holdout_set_from_training_data's score is: -1726.009
# [485] random_holdout_set_from_training_data's score is: -1722.84
# [490] random_holdout_set_from_training_data's score is: -1721.117
# [495] random_holdout_set_from_training_data's score is: -1720.187
# [500] random_holdout_set_from_training_data's score is: -1719.575
# [510] random_holdout_set_from_training_data's score is: -1718.886
# [520] random_holdout_set_from_training_data's score is: -1713.63
# [530] random_holdout_set_from_training_data's score is: -1711.116
# [540] random_holdout_set_from_training_data's score is: -1707.383
# [550] random_holdout_set_from_training_data's score is: -1706.253
# [560] random_holdout_set_from_training_data's score is: -1701.953
# [570] random_holdout_set_from_training_data's score is: -1698.721
# [580] random_holdout_set_from_training_data's score is: -1696.097
# [590] random_holdout_set_from_training_data's score is: -1693.183
# [600] random_holdout_set_from_training_data's score is: -1690.096
# [610] random_holdout_set_from_training_data's score is: -1688.777
# [620] random_holdout_set_from_training_data's score is: -1685.784
# [630] random_holdout_set_from_training_data's score is: -1683.601
# [640] random_holdout_set_from_training_data's score is: -1681.614
# [650] random_holdout_set_from_training_data's score is: -1678.729
# [660] random_holdout_set_from_training_data's score is: -1677.525
# [670] random_holdout_set_from_training_data's score is: -1674.881
# [680] random_holdout_set_from_training_data's score is: -1673.533
# [690] random_holdout_set_from_training_data's score is: -1671.906
# [700] random_holdout_set_from_training_data's score is: -1669.404
# [710] random_holdout_set_from_training_data's score is: -1668.07
# [720] random_holdout_set_from_training_data's score is: -1666.48
# [730] random_holdout_set_from_training_data's score is: -1664.714
# [740] random_holdout_set_from_training_data's score is: -1663.494
# [750] random_holdout_set_from_training_data's score is: -1661.599
# [760] random_holdout_set_from_training_data's score is: -1660.217
# [770] random_holdout_set_from_training_data's score is: -1659.047
# [780] random_holdout_set_from_training_data's score is: -1657.703
# [790] random_holdout_set_from_training_data's score is: -1655.811
# [800] random_holdout_set_from_training_data's score is: -1653.678
# [810] random_holdout_set_from_training_data's score is: -1652.777
# [820] random_holdout_set_from_training_data's score is: -1652.601
# [830] random_holdout_set_from_training_data's score is: -1651.057
# [840] random_holdout_set_from_training_data's score is: -1649.794
# [850] random_holdout_set_from_training_data's score is: -1647.865
# [860] random_holdout_set_from_training_data's score is: -1646.317
# [870] random_holdout_set_from_training_data's score is: -1645.172
# [880] random_holdout_set_from_training_data's score is: -1643.15
# [890] random_holdout_set_from_training_data's score is: -1641.319
# [900] random_holdout_set_from_training_data's score is: -1640.307
# [910] random_holdout_set_from_training_data's score is: -1639.693
# [920] random_holdout_set_from_training_data's score is: -1637.853
# [930] random_holdout_set_from_training_data's score is: -1636.702
# [940] random_holdout_set_from_training_data's score is: -1635.327
# [950] random_holdout_set_from_training_data's score is: -1634.256
# [960] random_holdout_set_from_training_data's score is: -1632.242
# [970] random_holdout_set_from_training_data's score is: -1630.952
# [980] random_holdout_set_from_training_data's score is: -1628.482
# [990] random_holdout_set_from_training_data's score is: -1626.439
# [1000] random_holdout_set_from_training_data's score is: -1624.649
# [1020] random_holdout_set_from_training_data's score is: -1620.715
# [1040] random_holdout_set_from_training_data's score is: -1617.569
# [1060] random_holdout_set_from_training_data's score is: -1615.099
# [1080] random_holdout_set_from_training_data's score is: -1612.702
# [1100] random_holdout_set_from_training_data's score is: -1611.397
# [1120] random_holdout_set_from_training_data's score is: -1609.906
# [1140] random_holdout_set_from_training_data's score is: -1606.435
# [1160] random_holdout_set_from_training_data's score is: -1604.0
# [1180] random_holdout_set_from_training_data's score is: -1601.516
# [1200] random_holdout_set_from_training_data's score is: -1598.362
# [1220] random_holdout_set_from_training_data's score is: -1597.102
# [1240] random_holdout_set_from_training_data's score is: -1594.735
# [1260] random_holdout_set_from_training_data's score is: -1590.986
# [1280] random_holdout_set_from_training_data's score is: -1589.364
# [1300] random_holdout_set_from_training_data's score is: -1587.364
# [1320] random_holdout_set_from_training_data's score is: -1585.316
# [1340] random_holdout_set_from_training_data's score is: -1583.079
# [1360] random_holdout_set_from_training_data's score is: -1580.825
# [1380] random_holdout_set_from_training_data's score is: -1577.933
# [1400] random_holdout_set_from_training_data's score is: -1575.607
# [1420] random_holdout_set_from_training_data's score is: -1573.874
# [1440] random_holdout_set_from_training_data's score is: -1571.753
# [1460] random_holdout_set_from_training_data's score is: -1570.928
# [1480] random_holdout_set_from_training_data's score is: -1568.937
# [1500] random_holdout_set_from_training_data's score is: -1567.722
# [1520] random_holdout_set_from_training_data's score is: -1566.066
# [1540] random_holdout_set_from_training_data's score is: -1564.334
# [1560] random_holdout_set_from_training_data's score is: -1562.26
# [1580] random_holdout_set_from_training_data's score is: -1561.154
# [1600] random_holdout_set_from_training_data's score is: -1559.671
# [1620] random_holdout_set_from_training_data's score is: -1558.245
# [1640] random_holdout_set_from_training_data's score is: -1557.01
# [1660] random_holdout_set_from_training_data's score is: -1555.907
# [1680] random_holdout_set_from_training_data's score is: -1554.861
# [1700] random_holdout_set_from_training_data's score is: -1553.09
# [1720] random_holdout_set_from_training_data's score is: -1551.476
# [1740] random_holdout_set_from_training_data's score is: -1550.481
# [1760] random_holdout_set_from_training_data's score is: -1549.717
# [1780] random_holdout_set_from_training_data's score is: -1548.299
# [1800] random_holdout_set_from_training_data's score is: -1546.825
# [1820] random_holdout_set_from_training_data's score is: -1545.636
# [1840] random_holdout_set_from_training_data's score is: -1544.101
# [1860] random_holdout_set_from_training_data's score is: -1543.197
# [1880] random_holdout_set_from_training_data's score is: -1542.128
# [1900] random_holdout_set_from_training_data's score is: -1541.667
# [1920] random_holdout_set_from_training_data's score is: -1540.11
# [1940] random_holdout_set_from_training_data's score is: -1539.248
# [1960] random_holdout_set_from_training_data's score is: -1537.942
# [1980] random_holdout_set_from_training_data's score is: -1535.82
# [2000] random_holdout_set_from_training_data's score is: -1534.388
# [2100] random_holdout_set_from_training_data's score is: -1528.821
# [2200] random_holdout_set_from_training_data's score is: -1523.064
# [2300] random_holdout_set_from_training_data's score is: -1519.205
# [2400] random_holdout_set_from_training_data's score is: -1514.462
# [2500] random_holdout_set_from_training_data's score is: -1509.46
# [2600] random_holdout_set_from_training_data's score is: -1506.338
# [2700] random_holdout_set_from_training_data's score is: -1501.21
# [2800] random_holdout_set_from_training_data's score is: -1498.343
# [2900] random_holdout_set_from_training_data's score is: -1493.34
# [3000] random_holdout_set_from_training_data's score is: -1489.163
# [3100] random_holdout_set_from_training_data's score is: -1485.462
# [3200] random_holdout_set_from_training_data's score is: -1482.701
# [3300] random_holdout_set_from_training_data's score is: -1480.119
# [3400] random_holdout_set_from_training_data's score is: -1476.53
# [3500] random_holdout_set_from_training_data's score is: -1473.507
# [3600] random_holdout_set_from_training_data's score is: -1471.319
# [3700] random_holdout_set_from_training_data's score is: -1468.357
# [3800] random_holdout_set_from_training_data's score is: -1466.461
# [3900] random_holdout_set_from_training_data's score is: -1463.721
# [4000] random_holdout_set_from_training_data's score is: -1462.302
# [4100] random_holdout_set_from_training_data's score is: -1460.236
# [4200] random_holdout_set_from_training_data's score is: -1457.825
# [4300] random_holdout_set_from_training_data's score is: -1455.55
# [4400] random_holdout_set_from_training_data's score is: -1454.81
# [4500] random_holdout_set_from_training_data's score is: -1452.591
# [4600] random_holdout_set_from_training_data's score is: -1451.023
# [4700] random_holdout_set_from_training_data's score is: -1449.769
# [4800] random_holdout_set_from_training_data's score is: -1448.185
# [4900] random_holdout_set_from_training_data's score is: -1447.035
# [5000] random_holdout_set_from_training_data's score is: -1445.758
# [5100] random_holdout_set_from_training_data's score is: -1444.167
# [5200] random_holdout_set_from_training_data's score is: -1442.953
# [5300] random_holdout_set_from_training_data's score is: -1441.824
# [5400] random_holdout_set_from_training_data's score is: -1440.795
# [5500] random_holdout_set_from_training_data's score is: -1439.475
# [5600] random_holdout_set_from_training_data's score is: -1437.855
# [5700] random_holdout_set_from_training_data's score is: -1435.531
# [5800] random_holdout_set_from_training_data's score is: -1434.044
# [5900] random_holdout_set_from_training_data's score is: -1433.025
# [6000] random_holdout_set_from_training_data's score is: -1432.211
# [6100] random_holdout_set_from_training_data's score is: -1431.365
# [6200] random_holdout_set_from_training_data's score is: -1430.738
# [6300] random_holdout_set_from_training_data's score is: -1429.822
# [6400] random_holdout_set_from_training_data's score is: -1428.432
# [6500] random_holdout_set_from_training_data's score is: -1426.931
# [6600] random_holdout_set_from_training_data's score is: -1426.187
# [6700] random_holdout_set_from_training_data's score is: -1425.247
# [6800] random_holdout_set_from_training_data's score is: -1424.578
# [6900] random_holdout_set_from_training_data's score is: -1423.684
# [7000] random_holdout_set_from_training_data's score is: -1422.698
# [7100] random_holdout_set_from_training_data's score is: -1421.742
# [7200] random_holdout_set_from_training_data's score is: -1420.413
# [7300] random_holdout_set_from_training_data's score is: -1419.792
# [7400] random_holdout_set_from_training_data's score is: -1419.415
# [7500] random_holdout_set_from_training_data's score is: -1418.928
# [7600] random_holdout_set_from_training_data's score is: -1418.625
# [7700] random_holdout_set_from_training_data's score is: -1417.184
# [7800] random_holdout_set_from_training_data's score is: -1416.322
# [7900] random_holdout_set_from_training_data's score is: -1416.414
# [8000] random_holdout_set_from_training_data's score is: -1415.12
# [8100] random_holdout_set_from_training_data's score is: -1414.218
# [8200] random_holdout_set_from_training_data's score is: -1413.901
# [8300] random_holdout_set_from_training_data's score is: -1413.267
# [8400] random_holdout_set_from_training_data's score is: -1412.761
# [8500] random_holdout_set_from_training_data's score is: -1412.111
# [8600] random_holdout_set_from_training_data's score is: -1411.564
# [8700] random_holdout_set_from_training_data's score is: -1410.704
# [8800] random_holdout_set_from_training_data's score is: -1410.032
# [8900] random_holdout_set_from_training_data's score is: -1408.797
# [9000] random_holdout_set_from_training_data's score is: -1408.255
# [9100] random_holdout_set_from_training_data's score is: -1407.423
# [9200] random_holdout_set_from_training_data's score is: -1406.72
# [9300] random_holdout_set_from_training_data's score is: -1406.155
# [9400] random_holdout_set_from_training_data's score is: -1405.155
# [9500] random_holdout_set_from_training_data's score is: -1404.433
# [9600] random_holdout_set_from_training_data's score is: -1403.971
# [9700] random_holdout_set_from_training_data's score is: -1403.369
# [9800] random_holdout_set_from_training_data's score is: -1403.134
# [9900] random_holdout_set_from_training_data's score is: -1402.299
# The number of estimators that were the best for this training dataset: 9900
# The best score on the holdout set: -1402.2990019867875
# Finished training the pipeline!
# Total training time:
# 1:07:58
#
#
# Here are the results from our GradientBoostingRegressor
# predicting price_m2
# Calculating feature responses, for advanced analytics.
# The printed list will only contain at most the top 100 features.
# +----+-----------------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------+
# |    | Feature Name          |   Importance |    Delta |   FR_Decrementing |   FR_Incrementing |   FRD_abs |   FRI_abs |   FRD_MAD |   FRI_MAD |
# |----+-----------------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------|
# |  9 | building_year_no_info |       0.0098 |   0.2116 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  7 | market_type           |       0.0121 |   0.2317 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 10 | building_type_apart   |       0.0162 |   0.1767 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  4 | floor                 |       0.0168 |   1.3525 |         -298.7047 |           31.7707 |  378.4239 |  131.3758 |  104.3379 |   83.0755 |
# |  3 | desc_len              |       0.0251 | 576.1517 |          -76.1318 |           91.9044 |  303.4745 |  225.5282 |  176.7125 |  141.0370 |
# |  2 | building_year         |       0.0405 |  16.0281 |          183.7221 |         -361.0653 |  668.9267 |  609.2275 |  438.1343 |  334.2121 |
# |  1 | building_type         |       0.0457 |   0.3953 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# |  8 | size                  |       0.0511 |  14.5911 |          605.7323 |         -302.5061 |  746.2370 |  465.4217 |  494.4523 |  353.2362 |
# |  0 | building_height       |       0.0543 |   1.7174 |         -193.7945 |          175.1120 |  340.5954 |  328.7686 |  276.1932 |  249.0569 |
# |  5 | lat                   |       0.3092 |   0.6883 |        -1469.2969 |         -422.0508 | 2662.0419 | 3451.8096 | 2053.7232 | 2008.0610 |
# |  6 | lon                   |       0.4191 |   0.9425 |        -1811.6919 |        -1912.2842 | 2490.5541 | 2360.3080 | 1860.3351 | 1779.0072 |
# +----+-----------------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------+
#
#
# *******
# Legend:
# Importance = Feature Importance
#      Explanation: A weighted measure of how much of the variance the model is able to explain is due to this column
# FR_delta = Feature Response Delta Amount
#      Explanation: Amount this column was incremented or decremented by to calculate the feature reponses
# FR_Decrementing = Feature Response From Decrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to subtracting one FR_delta amount from every value in this column
# FR_Incrementing = Feature Response From Incrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to adding one FR_delta amount to every value in this column
# FRD_MAD = Feature Response From Decrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if decrementing this feature provokes strong changes that are both positive and negative
# FRI_MAD = Feature Response From Incrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if incrementing this feature provokes strong changes that are both positive and negative
# FRD_abs = Feature Response From Decrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to subtracting one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# FRI_abs = Feature Response From Incrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to adding one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# *******
#
# None
#
#
# ***********************************************
# Advanced scoring metrics for the trained regression model on this particular dataset:
#
# Here is the overall RMSE for these predictions:
# 1423.8630320016705
#
# Here is the average of the predictions:
# 7926.638125065297
#
# Here is the average actual value on this validation set:
# 7938.290520451153
#
# Here is the median prediction:
# 7411.082933103757
#
# Here is the median actual value:
# 7377.96
#
# Here is the mean absolute error:
# 873.0633106139331
#
# Here is the median absolute error (robust to outliers):
# 548.1039795534455
#
# Here is the explained variance:
# 0.8371324513946392
#
# Here is the R-squared value:
# 0.8371215430803481
# Count of positive differences (prediction > actual):
# 19412
# Count of negative differences:
# 17383
# Average positive difference:
# 816.392299243153
# Average negative difference:
# -936.3491457821744
#
#
# ***********************************************
#
#
#
#
# We have saved the trained pipeline to a filed called "auto_ml_saved_pipeline.dill"
# It is saved in the directory:
# /home/antoni/repos/flats/prototypes
# To use it to get predictions, please follow the following flow (adjusting for your own uses as necessary:
#
#
# `from auto_ml.utils_models import load_ml_model
# `trained_ml_pipeline = load_ml_model("auto_ml_saved_pipeline.dill")
# `trained_ml_pipeline.predict(data)`
#
#
# Note that this pickle/dill file can only be loaded in an environment with the same modules installed, and running the same Python version.
# This version of Python is:
# sys.version_info(major=3, minor=7, micro=3, releaselevel='final', serial=0)
#
#
# When passing in new data to get predictions on, columns that were not present (or were not found to be useful) in the training data will be silently ignored.
# It is worthwhile to make sure that you feed in all the most useful data points though, to make sure you can get the highest quality predictions.
# [7873.9988193923, 8862.160906367128, 6005.109806126594, 10687.158597681524, 14026.523365689322, 9965.766727484419, 6346.830683046741, 10566.787273453001, 8119.7508444175655, 5594.5136196920885, 10035.780005469818, 8338.525452164185, 15792.696285847262, 3685.836240964744, 5707.19962064542, 11038.40243993955, 4202.92628834287, 4187.461275535307, 4539.506920623795, 7650.187525352915, 14222.087529910124, 6527.9859208312855, 5047.394016721926, 4221.146289361988, 3436.207518573542, 10355.592452081857, 6973.406987156361, 7676.77344028294, 8992.311310165045, 13760.830334951825, 11696.935122829556, 10279.662264897188, 9797.704505055102, 9516.250662351016, 4813.13482571223, 6485.117485331148, 6012.125471384699, 4234.671201541674, 14781.140998354957, 6702.356281658444, 6521.137558086663, 12025.622450286512, 4798.269916295581, 8824.658146254593, 22345.49083009031, 6890.989292272624, 12496.326574933475, 10931.02650759489, 7970.730511416926, 8187.075297333766, 5785.10633352982, 8602.87904072505, 4802.3855892144575, 5493.6941290940995, 6765.27455856451, 10516.182673641808, 7396.984775947465, 6754.620201692583, 10449.366307360599, 5306.31604882685, 11041.939929134178, 14838.914915121224, 4675.5681887141245, 5465.090303623126, 4501.762937285793, 3514.4117070584202, 7312.663144892327, 6795.102805430863, 5577.470915364644, 7751.472600968018, 15682.845682345796, 6474.008112414692, 4181.079069472721, 5679.087251768746, 7081.147781145038, 7862.0983810620255, 8689.068456131252, 6571.77213587528, 5027.247264878029, 8249.31991861288, 8166.123657951008, 8239.880895078497, 6368.788874570484, 11296.47501731002, 10278.834942988313, 13322.468114421865, 2994.871152774699, 7325.775426631434, 5110.282250166337, 11294.26133825515, 7845.553404437182, 7694.440561573217, 5845.680824371932, 7226.972446641646, 5412.086473242101, 10468.123591374906, 3848.039903694629, 12434.794216176406, 10283.712885858815, 5950.324965670544, 3888.2148264181665, 6447.881597475436, 4049.3874537800184, 7822.581917462833, 8188.565507069747, 5532.922503458066, 9716.130230909286, 4782.508220564424, 5967.709432074872, 8982.461623608957, 7785.252157424575, 6376.003266767008, 11663.518057672409, 12715.889362574662, 6540.047202589891, 7157.205802760836, 870.2851913972617, 5207.772799723363, 5666.572107245742, 16296.087877841132, 16168.883271509058, 10793.455250132853, 10953.001288906073, 9710.666139555757, 3830.5239475945336, 11552.617531795646, 12918.76257363362, 8295.890282197486, 10442.336187140001, 6710.622447390704, 6630.157532548038, 6945.043334760858, 5851.076691543021, 6899.428214531221, 8883.279390741489, 12571.361989148687, 8181.005969389614, 6636.714268601302, 16581.3776007627, 4008.36134525609, 4453.021386842614, 8572.181197592601, 7854.742971669975, 3876.126126665327, 6626.7009761737245, 4478.791216072347, 7754.010756873721, 6289.648734271934, 10765.127990481335, 6766.398919516401, 15405.164542639393, 9722.728665042378, 9585.430210792196, 9317.27171181676, 12981.658003115735, 6068.535266048537, 10562.354329649448, 6473.078800777713, 10830.522698100516, 8861.767394413231, 6492.586786323689, 6117.271700449288, 8001.873224740366, 2421.7822978270297, 1696.3999082888397, 5895.070672517033, 6421.267279159088, 10820.344834010295, 9841.936468162523, 5520.019334543786, 7329.718718486513, 7198.062433995209, 3249.703438241282, 11475.967953012905, 11954.820871723086, 13291.0654927852, 5694.8249935093645, 4154.023585927864, 5147.756349754302, 7224.672746476226, 4733.711238449011, 6877.398424807326, 9909.543754045264, 8713.101733246494, 7786.042074030355, 5147.919171884933, 6679.485850737042, 8815.91663873749, 1377.7231576190773, 6071.804013564149, 8165.7446814884, 11249.956470354675, 10462.257680341258, 4549.420457141938, 4589.9843747593395, 5400.06325999613, 10576.01110868989, 6363.372934052227, 11284.417234324119, 12930.867124457947, 14587.59986292359, 15020.446797570585, 6052.902411723551, 5131.3522343385175, 10599.803294492858, 9519.765153992868, 4878.660962796694, 8625.930169816913, 421 ...
